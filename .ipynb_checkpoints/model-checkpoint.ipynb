# %% [markdown]
# # Import packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from tensorflow.keras.layers.experimental.preprocessing import CategoryEncoding
from tensorflow.keras.layers.experimental.preprocessing import StringLookup

# %% [markdown]
# # Preprocessing

# %%
dataframe  = pd.read_csv('data/term-deposit-marketing-2020.csv')
dataframe['y'] = dataframe.y.replace(to_replace=['no', 'yes'], value=[0, 1])
dataframe
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 39995   53    technician   married   tertiary      no      395      no   no
# 39996   30    management    single   tertiary      no     3340      no   no
# 39997   54         admin  divorced  secondary      no      200      no   no
# 39998   34    management   married   tertiary      no     1047      no   no
# 39999   38    technician   married  secondary      no     1442     yes   no
#
#         contact  day month  duration  campaign  y
# 0       unknown    5   may       261         1  0
# 1       unknown    5   may       151         1  0
# 2       unknown    5   may        76         1  0
# 3       unknown    5   may        92         1  0
# 4       unknown    5   may       198         1  0
# ...         ...  ...   ...       ...       ... ..
# 39995  cellular    3   jun       107         1  0
# 39996  cellular    3   jun       238         3  1
# 39997  cellular    3   jun       170         1  1
# 39998  cellular    3   jun       342         1  0
# 39999  cellular    3   jun       113         1  0
#
# [40000 rows x 14 columns]

# %% [markdown]
# ### Statistics

# %%
dataframe.describe().transpose()
# Out:
#             count         mean          std     min    25%    50%     75%  \
# age       40000.0    40.544600     9.641776    19.0   33.0   39.0    48.0
# balance   40000.0  1274.277550  2903.769716 -8019.0   54.0  407.0  1319.0
# day       40000.0    16.017225     8.278127     1.0    8.0   17.0    21.0
# duration  40000.0   254.824300   259.366498     0.0  100.0  175.0   313.0
# campaign  40000.0     2.882175     3.239051     1.0    1.0    2.0     3.0
# y         40000.0     0.072400     0.259152     0.0    0.0    0.0     0.0
#
#                max
# age           95.0
# balance   102127.0
# day           31.0
# duration    4918.0
# campaign      63.0
# y              1.0

# %% [markdown]
# ## Analyze imbalance in the targets

# %%
neg, pos = np.bincount(dataframe['y'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 40000
#     Positive: 2896 (7.24% of total)

# %%
val_dataframe = dataframe.sample(frac=0.2, random_state=1337)
train_dataframe = dataframe.drop(val_dataframe.index)

print(
    "Using %d samples for training and %d for validation"
    % (len(train_dataframe), len(val_dataframe))
)
# Out:
# Using 32000 samples for training and 8000 for validation

# %%
counts = np.bincount(train_dataframe['y'])

weight_for_0 = 1.0 / counts[0] * (np.sum(counts))/2.0
weight_for_1 = 1.0 / counts[1] * (np.sum(counts))/2.0

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("y")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

train_ds = dataframe_to_dataset(train_dataframe)
val_ds = dataframe_to_dataset(val_dataframe)

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=49>, 'job': <tf.Tensor: shape=(), dtype=string, numpy=b'technician'>, 'marital': <tf.Tensor: shape=(), dtype=string, numpy=b'divorced'>, 'education': <tf.Tensor: shape=(), dtype=string, numpy=b'secondary'>, 'default': <tf.Tensor: shape=(), dtype=string, numpy=b'no'>, 'balance': <tf.Tensor: shape=(), dtype=int64, numpy=790>, 'housing': <tf.Tensor: shape=(), dtype=string, numpy=b'yes'>, 'loan': <tf.Tensor: shape=(), dtype=string, numpy=b'no'>, 'contact': <tf.Tensor: shape=(), dtype=string, numpy=b'cellular'>, 'day': <tf.Tensor: shape=(), dtype=int64, numpy=7>, 'month': <tf.Tensor: shape=(), dtype=string, numpy=b'aug'>, 'duration': <tf.Tensor: shape=(), dtype=int64, numpy=324>, 'campaign': <tf.Tensor: shape=(), dtype=int64, numpy=3>}
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %%
train_ds = train_ds.batch(2000)
val_ds = val_ds.batch(2000)

# %% [markdown]
# ### Feature preprocessing with Keras layers using one-hot encoding

# %%
def encode_numerical_feature(feature, name, dataset):
    normalizer = Normalization()

    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    normalizer.adapt(feature_ds)

    encoded_feature = normalizer(feature)
    return encoded_feature

def encode_string_categorical_feature(feature, name, dataset):
    index = StringLookup()

    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    index.adapt(feature_ds)

    encoded_feature = index(feature)

    encoder = CategoryEncoding(output_mode="binary")

    feature_ds = feature_ds.map(index)

    encoder.adapt(feature_ds)

    encoded_feature = encoder(encoded_feature)
    return encoded_feature

# %% [markdown]
# ### Build a model

# %%
job = keras.Input(shape=(1,), name="job", dtype="string")
marital = keras.Input(shape=(1,), name="marital", dtype="string")
education = keras.Input(shape=(1,), name="education", dtype="string")
default = keras.Input(shape=(1,), name="default", dtype="string")
housing = keras.Input(shape=(1,), name="housing", dtype="string")
loan = keras.Input(shape=(1,), name="loan", dtype="string")
contact = keras.Input(shape=(1,), name="contact", dtype="string")
month = keras.Input(shape=(1,), name="month", dtype="string")

age = keras.Input(shape=(1,), name="age")
balance = keras.Input(shape=(1,), name="balance")
day = keras.Input(shape=(1,), name="day")
duration = keras.Input(shape=(1,), name="duration")
campaign = keras.Input(shape=(1,), name="campaign")

all_inputs = [
    job,
    marital,
    education,
    default,
    housing,
    loan,
    contact,
    month,
    age,
    balance,
    day,
    duration,
    campaign
]

job_encoded = encode_string_categorical_feature(job, "job", train_ds)
marital_encoded = encode_string_categorical_feature(marital, "marital", train_ds)
education_encoded = encode_string_categorical_feature(education, "education", train_ds)
default_encoded = encode_string_categorical_feature(default, "default", train_ds)
housing_encoded = encode_string_categorical_feature(housing, "housing", train_ds)
loan_encoded = encode_string_categorical_feature(loan, "loan", train_ds)
contact_encoded = encode_string_categorical_feature(contact, "contact", train_ds)
month_encoded = encode_string_categorical_feature(month, "month", train_ds)

age_encoded = encode_numerical_feature(age, "age", train_ds)
balance_encoded = encode_numerical_feature(balance, "balance", train_ds)
day_encoded = encode_numerical_feature(day, "day", train_ds)
duration_encoded = encode_numerical_feature(duration, "duration", train_ds)
campaign_encoded = encode_numerical_feature(campaign, "campaign", train_ds)

all_features = layers.concatenate(
    [
        job_encoded,
        marital_encoded,
        education_encoded,
        default_encoded,
        housing_encoded,
        loan_encoded,
        contact_encoded,
        month_encoded,
        age_encoded,
        balance_encoded,
        day_encoded,
        duration_encoded,
        campaign_encoded
    ]
)

# %%
x = layers.Dense(32, activation="relu")(all_features)
x = layers.Dropout(0.5)(x)
output = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(all_inputs, output)

# %%
metrics = [
    keras.metrics.FalseNegatives(name="fn"),
    keras.metrics.FalsePositives(name="fp"),
    keras.metrics.TrueNegatives(name="tn"),
    keras.metrics.TruePositives(name="tp"),
    keras.metrics.BinaryAccuracy(name='accuracy'),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
    keras.metrics.AUC(name='auc'),
]

model.compile(
    optimizer=keras.optimizers.Adam(1e-2), loss="binary_crossentropy", metrics=metrics
)

# %%
keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# # Train the model

# %%
class_weight = {0: weight_for_0, 1: weight_for_1}

model.fit(
    train_ds,
    epochs=50,
    verbose=2,
    validation_data=val_ds,
    class_weight=class_weight,
)
# Out:
# Epoch 1/50
# 16/16 - 1s - loss: 0.5610 - fn: 660.0000 - fp: 8896.0000 - tn: 20816.0000 - tp: 1628.0000 - accuracy: 0.7014 - precision: 0.1547 - recall: 0.7115 - auc: 0.7834 - val_loss: 0.4249 - val_fn: 98.0000 - val_fp: 1158.0000 - val_tn: 6234.0000 - val_tp: 510.0000 - val_accuracy: 0.8430 - val_precision: 0.3058 - val_recall: 0.8388 - val_auc: 0.9155
# Epoch 2/50
# 16/16 - 0s - loss: 0.4189 - fn: 432.0000 - fp: 4812.0000 - tn: 24900.0000 - tp: 1856.0000 - accuracy: 0.8361 - precision: 0.2783 - recall: 0.8112 - auc: 0.8988 - val_loss: 0.3919 - val_fn: 78.0000 - val_fp: 1092.0000 - val_tn: 6300.0000 - val_tp: 530.0000 - val_accuracy: 0.8537 - val_precision: 0.3268 - val_recall: 0.8717 - val_auc: 0.9314
# Epoch 3/50
# 16/16 - 0s - loss: 0.3801 - fn: 342.0000 - fp: 4378.0000 - tn: 25334.0000 - tp: 1946.0000 - accuracy: 0.8525 - precision: 0.3077 - recall: 0.8505 - auc: 0.9180 - val_loss: 0.3622 - val_fn: 71.0000 - val_fp: 1111.0000 - val_tn: 6281.0000 - val_tp: 537.0000 - val_accuracy: 0.8522 - val_precision: 0.3258 - val_recall: 0.8832 - val_auc: 0.9364
# Epoch 4/50
# 16/16 - 0s - loss: 0.3587 - fn: 315.0000 - fp: 4439.0000 - tn: 25273.0000 - tp: 1973.0000 - accuracy: 0.8514 - precision: 0.3077 - recall: 0.8623 - auc: 0.9250 - val_loss: 0.3576 - val_fn: 60.0000 - val_fp: 1216.0000 - val_tn: 6176.0000 - val_tp: 548.0000 - val_accuracy: 0.8405 - val_precision: 0.3107 - val_recall: 0.9013 - val_auc: 0.9389
# Epoch 5/50
# 16/16 - 0s - loss: 0.3443 - fn: 263.0000 - fp: 4585.0000 - tn: 25127.0000 - tp: 2025.0000 - accuracy: 0.8485 - precision: 0.3064 - recall: 0.8851 - auc: 0.9282 - val_loss: 0.3341 - val_fn: 59.0000 - val_fp: 1174.0000 - val_tn: 6218.0000 - val_tp: 549.0000 - val_accuracy: 0.8459 - val_precision: 0.3186 - val_recall: 0.9030 - val_auc: 0.9405
# Epoch 6/50
# 16/16 - 1s - loss: 0.3322 - fn: 251.0000 - fp: 4572.0000 - tn: 25140.0000 - tp: 2037.0000 - accuracy: 0.8493 - precision: 0.3082 - recall: 0.8903 - auc: 0.9324 - val_loss: 0.3448 - val_fn: 50.0000 - val_fp: 1255.0000 - val_tn: 6137.0000 - val_tp: 558.0000 - val_accuracy: 0.8369 - val_precision: 0.3078 - val_recall: 0.9178 - val_auc: 0.9421
# Epoch 7/50
# 16/16 - 0s - loss: 0.3260 - fn: 214.0000 - fp: 4654.0000 - tn: 25058.0000 - tp: 2074.0000 - accuracy: 0.8479 - precision: 0.3083 - recall: 0.9065 - auc: 0.9344 - val_loss: 0.3423 - val_fn: 46.0000 - val_fp: 1293.0000 - val_tn: 6099.0000 - val_tp: 562.0000 - val_accuracy: 0.8326 - val_precision: 0.3030 - val_recall: 0.9243 - val_auc: 0.9431
# Epoch 8/50
# 16/16 - 0s - loss: 0.3275 - fn: 233.0000 - fp: 4771.0000 - tn: 24941.0000 - tp: 2055.0000 - accuracy: 0.8436 - precision: 0.3011 - recall: 0.8982 - auc: 0.9338 - val_loss: 0.3277 - val_fn: 54.0000 - val_fp: 1200.0000 - val_tn: 6192.0000 - val_tp: 554.0000 - val_accuracy: 0.8432 - val_precision: 0.3158 - val_recall: 0.9112 - val_auc: 0.9430
# Epoch 9/50
# 16/16 - 0s - loss: 0.3262 - fn: 201.0000 - fp: 4904.0000 - tn: 24808.0000 - tp: 2087.0000 - accuracy: 0.8405 - precision: 0.2985 - recall: 0.9122 - auc: 0.9341 - val_loss: 0.3080 - val_fn: 50.0000 - val_fp: 1173.0000 - val_tn: 6219.0000 - val_tp: 558.0000 - val_accuracy: 0.8471 - val_precision: 0.3224 - val_recall: 0.9178 - val_auc: 0.9440
# Epoch 10/50
# 16/16 - 0s - loss: 0.3195 - fn: 189.0000 - fp: 4877.0000 - tn: 24835.0000 - tp: 2099.0000 - accuracy: 0.8417 - precision: 0.3009 - recall: 0.9174 - auc: 0.9366 - val_loss: 0.3207 - val_fn: 46.0000 - val_fp: 1234.0000 - val_tn: 6158.0000 - val_tp: 562.0000 - val_accuracy: 0.8400 - val_precision: 0.3129 - val_recall: 0.9243 - val_auc: 0.9447
# Epoch 11/50
# 16/16 - 0s - loss: 0.3177 - fn: 188.0000 - fp: 4695.0000 - tn: 25017.0000 - tp: 2100.0000 - accuracy: 0.8474 - precision: 0.3091 - recall: 0.9178 - auc: 0.9371 - val_loss: 0.3289 - val_fn: 47.0000 - val_fp: 1242.0000 - val_tn: 6150.0000 - val_tp: 561.0000 - val_accuracy: 0.8389 - val_precision: 0.3111 - val_recall: 0.9227 - val_auc: 0.9446
# Epoch 12/50
# 16/16 - 0s - loss: 0.3237 - fn: 187.0000 - fp: 5021.0000 - tn: 24691.0000 - tp: 2101.0000 - accuracy: 0.8372 - precision: 0.2950 - recall: 0.9183 - auc: 0.9349 - val_loss: 0.3556 - val_fn: 37.0000 - val_fp: 1375.0000 - val_tn: 6017.0000 - val_tp: 571.0000 - val_accuracy: 0.8235 - val_precision: 0.2934 - val_recall: 0.9391 - val_auc: 0.9444
# Epoch 13/50
# 16/16 - 0s - loss: 0.3210 - fn: 191.0000 - fp: 4995.0000 - tn: 24717.0000 - tp: 2097.0000 - accuracy: 0.8379 - precision: 0.2957 - recall: 0.9165 - auc: 0.9356 - val_loss: 0.3403 - val_fn: 43.0000 - val_fp: 1312.0000 - val_tn: 6080.0000 - val_tp: 565.0000 - val_accuracy: 0.8306 - val_precision: 0.3010 - val_recall: 0.9293 - val_auc: 0.9444
# Epoch 14/50
# 16/16 - 0s - loss: 0.3183 - fn: 172.0000 - fp: 5075.0000 - tn: 24637.0000 - tp: 2116.0000 - accuracy: 0.8360 - precision: 0.2943 - recall: 0.9248 - auc: 0.9369 - val_loss: 0.2909 - val_fn: 61.0000 - val_fp: 1084.0000 - val_tn: 6308.0000 - val_tp: 547.0000 - val_accuracy: 0.8569 - val_precision: 0.3354 - val_recall: 0.8997 - val_auc: 0.9442
# Epoch 15/50
# 16/16 - 0s - loss: 0.3162 - fn: 178.0000 - fp: 4904.0000 - tn: 24808.0000 - tp: 2110.0000 - accuracy: 0.8412 - precision: 0.3008 - recall: 0.9222 - auc: 0.9377 - val_loss: 0.3321 - val_fn: 41.0000 - val_fp: 1257.0000 - val_tn: 6135.0000 - val_tp: 567.0000 - val_accuracy: 0.8378 - val_precision: 0.3109 - val_recall: 0.9326 - val_auc: 0.9448
# Epoch 16/50
# 16/16 - 0s - loss: 0.3184 - fn: 180.0000 - fp: 5094.0000 - tn: 24618.0000 - tp: 2108.0000 - accuracy: 0.8352 - precision: 0.2927 - recall: 0.9213 - auc: 0.9369 - val_loss: 0.3357 - val_fn: 39.0000 - val_fp: 1319.0000 - val_tn: 6073.0000 - val_tp: 569.0000 - val_accuracy: 0.8303 - val_precision: 0.3014 - val_recall: 0.9359 - val_auc: 0.9454
# Epoch 17/50
# 16/16 - 0s - loss: 0.3095 - fn: 165.0000 - fp: 5150.0000 - tn: 24562.0000 - tp: 2123.0000 - accuracy: 0.8339 - precision: 0.2919 - recall: 0.9279 - auc: 0.9396 - val_loss: 0.2762 - val_fn: 58.0000 - val_fp: 1040.0000 - val_tn: 6352.0000 - val_tp: 550.0000 - val_accuracy: 0.8627 - val_precision: 0.3459 - val_recall: 0.9046 - val_auc: 0.9450
# Epoch 18/50
# 16/16 - 0s - loss: 0.3130 - fn: 179.0000 - fp: 5000.0000 - tn: 24712.0000 - tp: 2109.0000 - accuracy: 0.8382 - precision: 0.2967 - recall: 0.9218 - auc: 0.9384 - val_loss: 0.2937 - val_fn: 51.0000 - val_fp: 1145.0000 - val_tn: 6247.0000 - val_tp: 557.0000 - val_accuracy: 0.8505 - val_precision: 0.3273 - val_recall: 0.9161 - val_auc: 0.9453
# Epoch 19/50
# 16/16 - 0s - loss: 0.3137 - fn: 171.0000 - fp: 5162.0000 - tn: 24550.0000 - tp: 2117.0000 - accuracy: 0.8333 - precision: 0.2908 - recall: 0.9253 - auc: 0.9390 - val_loss: 0.2963 - val_fn: 53.0000 - val_fp: 1131.0000 - val_tn: 6261.0000 - val_tp: 555.0000 - val_accuracy: 0.8520 - val_precision: 0.3292 - val_recall: 0.9128 - val_auc: 0.9463
# Epoch 20/50
# 16/16 - 0s - loss: 0.3065 - fn: 177.0000 - fp: 4865.0000 - tn: 24847.0000 - tp: 2111.0000 - accuracy: 0.8424 - precision: 0.3026 - recall: 0.9226 - auc: 0.9408 - val_loss: 0.3063 - val_fn: 49.0000 - val_fp: 1185.0000 - val_tn: 6207.0000 - val_tp: 559.0000 - val_accuracy: 0.8457 - val_precision: 0.3205 - val_recall: 0.9194 - val_auc: 0.9455
# Epoch 21/50
# 16/16 - 0s - loss: 0.3081 - fn: 182.0000 - fp: 4910.0000 - tn: 24802.0000 - tp: 2106.0000 - accuracy: 0.8409 - precision: 0.3002 - recall: 0.9205 - auc: 0.9402 - val_loss: 0.3298 - val_fn: 44.0000 - val_fp: 1245.0000 - val_tn: 6147.0000 - val_tp: 564.0000 - val_accuracy: 0.8389 - val_precision: 0.3118 - val_recall: 0.9276 - val_auc: 0.9453
# Epoch 22/50
# 16/16 - 0s - loss: 0.3120 - fn: 161.0000 - fp: 5035.0000 - tn: 24677.0000 - tp: 2127.0000 - accuracy: 0.8376 - precision: 0.2970 - recall: 0.9296 - auc: 0.9396 - val_loss: 0.2883 - val_fn: 56.0000 - val_fp: 1082.0000 - val_tn: 6310.0000 - val_tp: 552.0000 - val_accuracy: 0.8577 - val_precision: 0.3378 - val_recall: 0.9079 - val_auc: 0.9464
# Epoch 23/50
# 16/16 - 0s - loss: 0.3085 - fn: 169.0000 - fp: 4838.0000 - tn: 24874.0000 - tp: 2119.0000 - accuracy: 0.8435 - precision: 0.3046 - recall: 0.9261 - auc: 0.9401 - val_loss: 0.3025 - val_fn: 54.0000 - val_fp: 1145.0000 - val_tn: 6247.0000 - val_tp: 554.0000 - val_accuracy: 0.8501 - val_precision: 0.3261 - val_recall: 0.9112 - val_auc: 0.9459
# Epoch 24/50
# 16/16 - 0s - loss: 0.3069 - fn: 154.0000 - fp: 4929.0000 - tn: 24783.0000 - tp: 2134.0000 - accuracy: 0.8412 - precision: 0.3021 - recall: 0.9327 - auc: 0.9404 - val_loss: 0.3134 - val_fn: 46.0000 - val_fp: 1216.0000 - val_tn: 6176.0000 - val_tp: 562.0000 - val_accuracy: 0.8422 - val_precision: 0.3161 - val_recall: 0.9243 - val_auc: 0.9452
# Epoch 25/50
# 16/16 - 0s - loss: 0.3121 - fn: 168.0000 - fp: 4935.0000 - tn: 24777.0000 - tp: 2120.0000 - accuracy: 0.8405 - precision: 0.3005 - recall: 0.9266 - auc: 0.9389 - val_loss: 0.3057 - val_fn: 48.0000 - val_fp: 1150.0000 - val_tn: 6242.0000 - val_tp: 560.0000 - val_accuracy: 0.8503 - val_precision: 0.3275 - val_recall: 0.9211 - val_auc: 0.9465
# Epoch 26/50
# 16/16 - 0s - loss: 0.3090 - fn: 169.0000 - fp: 4989.0000 - tn: 24723.0000 - tp: 2119.0000 - accuracy: 0.8388 - precision: 0.2981 - recall: 0.9261 - auc: 0.9397 - val_loss: 0.3196 - val_fn: 40.0000 - val_fp: 1239.0000 - val_tn: 6153.0000 - val_tp: 568.0000 - val_accuracy: 0.8401 - val_precision: 0.3143 - val_recall: 0.9342 - val_auc: 0.9459
# Epoch 27/50
# 16/16 - 0s - loss: 0.3096 - fn: 164.0000 - fp: 4996.0000 - tn: 24716.0000 - tp: 2124.0000 - accuracy: 0.8388 - precision: 0.2983 - recall: 0.9283 - auc: 0.9402 - val_loss: 0.3597 - val_fn: 33.0000 - val_fp: 1398.0000 - val_tn: 5994.0000 - val_tp: 575.0000 - val_accuracy: 0.8211 - val_precision: 0.2914 - val_recall: 0.9457 - val_auc: 0.9461
# Epoch 28/50
# 16/16 - 0s - loss: 0.3064 - fn: 175.0000 - fp: 4942.0000 - tn: 24770.0000 - tp: 2113.0000 - accuracy: 0.8401 - precision: 0.2995 - recall: 0.9235 - auc: 0.9413 - val_loss: 0.3535 - val_fn: 35.0000 - val_fp: 1364.0000 - val_tn: 6028.0000 - val_tp: 573.0000 - val_accuracy: 0.8251 - val_precision: 0.2958 - val_recall: 0.9424 - val_auc: 0.9456
# Epoch 29/50
# 16/16 - 0s - loss: 0.3086 - fn: 167.0000 - fp: 4963.0000 - tn: 24749.0000 - tp: 2121.0000 - accuracy: 0.8397 - precision: 0.2994 - recall: 0.9270 - auc: 0.9403 - val_loss: 0.3011 - val_fn: 54.0000 - val_fp: 1166.0000 - val_tn: 6226.0000 - val_tp: 554.0000 - val_accuracy: 0.8475 - val_precision: 0.3221 - val_recall: 0.9112 - val_auc: 0.9449
# Epoch 30/50
# 16/16 - 0s - loss: 0.3047 - fn: 153.0000 - fp: 5111.0000 - tn: 24601.0000 - tp: 2135.0000 - accuracy: 0.8355 - precision: 0.2946 - recall: 0.9331 - auc: 0.9411 - val_loss: 0.2800 - val_fn: 61.0000 - val_fp: 1074.0000 - val_tn: 6318.0000 - val_tp: 547.0000 - val_accuracy: 0.8581 - val_precision: 0.3374 - val_recall: 0.8997 - val_auc: 0.9453
# Epoch 31/50
# 16/16 - 0s - loss: 0.3109 - fn: 165.0000 - fp: 5066.0000 - tn: 24646.0000 - tp: 2123.0000 - accuracy: 0.8365 - precision: 0.2953 - recall: 0.9279 - auc: 0.9394 - val_loss: 0.3034 - val_fn: 49.0000 - val_fp: 1191.0000 - val_tn: 6201.0000 - val_tp: 559.0000 - val_accuracy: 0.8450 - val_precision: 0.3194 - val_recall: 0.9194 - val_auc: 0.9459
# Epoch 32/50
# 16/16 - 0s - loss: 0.3043 - fn: 163.0000 - fp: 4917.0000 - tn: 24795.0000 - tp: 2125.0000 - accuracy: 0.8413 - precision: 0.3018 - recall: 0.9288 - auc: 0.9416 - val_loss: 0.2893 - val_fn: 57.0000 - val_fp: 1093.0000 - val_tn: 6299.0000 - val_tp: 551.0000 - val_accuracy: 0.8562 - val_precision: 0.3352 - val_recall: 0.9062 - val_auc: 0.9454
# Epoch 33/50
# 16/16 - 0s - loss: 0.3039 - fn: 157.0000 - fp: 4947.0000 - tn: 24765.0000 - tp: 2131.0000 - accuracy: 0.8405 - precision: 0.3011 - recall: 0.9314 - auc: 0.9410 - val_loss: 0.3053 - val_fn: 49.0000 - val_fp: 1186.0000 - val_tn: 6206.0000 - val_tp: 559.0000 - val_accuracy: 0.8456 - val_precision: 0.3203 - val_recall: 0.9194 - val_auc: 0.9456
# Epoch 34/50
# 16/16 - 0s - loss: 0.3070 - fn: 165.0000 - fp: 4992.0000 - tn: 24720.0000 - tp: 2123.0000 - accuracy: 0.8388 - precision: 0.2984 - recall: 0.9279 - auc: 0.9412 - val_loss: 0.3219 - val_fn: 43.0000 - val_fp: 1238.0000 - val_tn: 6154.0000 - val_tp: 565.0000 - val_accuracy: 0.8399 - val_precision: 0.3134 - val_recall: 0.9293 - val_auc: 0.9466
# Epoch 35/50
# 16/16 - 0s - loss: 0.3028 - fn: 150.0000 - fp: 5033.0000 - tn: 24679.0000 - tp: 2138.0000 - accuracy: 0.8380 - precision: 0.2981 - recall: 0.9344 - auc: 0.9421 - val_loss: 0.2971 - val_fn: 53.0000 - val_fp: 1159.0000 - val_tn: 6233.0000 - val_tp: 555.0000 - val_accuracy: 0.8485 - val_precision: 0.3238 - val_recall: 0.9128 - val_auc: 0.9462
# Epoch 36/50
# 16/16 - 0s - loss: 0.3064 - fn: 165.0000 - fp: 5025.0000 - tn: 24687.0000 - tp: 2123.0000 - accuracy: 0.8378 - precision: 0.2970 - recall: 0.9279 - auc: 0.9410 - val_loss: 0.2936 - val_fn: 54.0000 - val_fp: 1141.0000 - val_tn: 6251.0000 - val_tp: 554.0000 - val_accuracy: 0.8506 - val_precision: 0.3268 - val_recall: 0.9112 - val_auc: 0.9462
# Epoch 37/50
# 16/16 - 0s - loss: 0.3015 - fn: 157.0000 - fp: 4937.0000 - tn: 24775.0000 - tp: 2131.0000 - accuracy: 0.8408 - precision: 0.3015 - recall: 0.9314 - auc: 0.9426 - val_loss: 0.2843 - val_fn: 58.0000 - val_fp: 1082.0000 - val_tn: 6310.0000 - val_tp: 550.0000 - val_accuracy: 0.8575 - val_precision: 0.3370 - val_recall: 0.9046 - val_auc: 0.9469
# Epoch 38/50
# 16/16 - 0s - loss: 0.3053 - fn: 176.0000 - fp: 4814.0000 - tn: 24898.0000 - tp: 2112.0000 - accuracy: 0.8441 - precision: 0.3049 - recall: 0.9231 - auc: 0.9412 - val_loss: 0.3050 - val_fn: 46.0000 - val_fp: 1191.0000 - val_tn: 6201.0000 - val_tp: 562.0000 - val_accuracy: 0.8454 - val_precision: 0.3206 - val_recall: 0.9243 - val_auc: 0.9468
# Epoch 39/50
# 16/16 - 0s - loss: 0.3053 - fn: 157.0000 - fp: 4988.0000 - tn: 24724.0000 - tp: 2131.0000 - accuracy: 0.8392 - precision: 0.2993 - recall: 0.9314 - auc: 0.9424 - val_loss: 0.3187 - val_fn: 44.0000 - val_fp: 1234.0000 - val_tn: 6158.0000 - val_tp: 564.0000 - val_accuracy: 0.8403 - val_precision: 0.3137 - val_recall: 0.9276 - val_auc: 0.9470
# Epoch 40/50
# 16/16 - 0s - loss: 0.3042 - fn: 157.0000 - fp: 4979.0000 - tn: 24733.0000 - tp: 2131.0000 - accuracy: 0.8395 - precision: 0.2997 - recall: 0.9314 - auc: 0.9415 - val_loss: 0.3175 - val_fn: 43.0000 - val_fp: 1261.0000 - val_tn: 6131.0000 - val_tp: 565.0000 - val_accuracy: 0.8370 - val_precision: 0.3094 - val_recall: 0.9293 - val_auc: 0.9465
# Epoch 41/50
# 16/16 - 0s - loss: 0.3006 - fn: 167.0000 - fp: 4900.0000 - tn: 24812.0000 - tp: 2121.0000 - accuracy: 0.8417 - precision: 0.3021 - recall: 0.9270 - auc: 0.9425 - val_loss: 0.3073 - val_fn: 51.0000 - val_fp: 1179.0000 - val_tn: 6213.0000 - val_tp: 557.0000 - val_accuracy: 0.8462 - val_precision: 0.3209 - val_recall: 0.9161 - val_auc: 0.9471
# Epoch 42/50
# 16/16 - 0s - loss: 0.3002 - fn: 160.0000 - fp: 4967.0000 - tn: 24745.0000 - tp: 2128.0000 - accuracy: 0.8398 - precision: 0.2999 - recall: 0.9301 - auc: 0.9423 - val_loss: 0.2948 - val_fn: 49.0000 - val_fp: 1152.0000 - val_tn: 6240.0000 - val_tp: 559.0000 - val_accuracy: 0.8499 - val_precision: 0.3267 - val_recall: 0.9194 - val_auc: 0.9472
# Epoch 43/50
# 16/16 - 0s - loss: 0.3014 - fn: 140.0000 - fp: 5001.0000 - tn: 24711.0000 - tp: 2148.0000 - accuracy: 0.8393 - precision: 0.3005 - recall: 0.9388 - auc: 0.9427 - val_loss: 0.2827 - val_fn: 52.0000 - val_fp: 1070.0000 - val_tn: 6322.0000 - val_tp: 556.0000 - val_accuracy: 0.8597 - val_precision: 0.3419 - val_recall: 0.9145 - val_auc: 0.9469
# Epoch 44/50
# 16/16 - 0s - loss: 0.3040 - fn: 168.0000 - fp: 4808.0000 - tn: 24904.0000 - tp: 2120.0000 - accuracy: 0.8445 - precision: 0.3060 - recall: 0.9266 - auc: 0.9414 - val_loss: 0.3033 - val_fn: 48.0000 - val_fp: 1163.0000 - val_tn: 6229.0000 - val_tp: 560.0000 - val_accuracy: 0.8486 - val_precision: 0.3250 - val_recall: 0.9211 - val_auc: 0.9468
# Epoch 45/50
# 16/16 - 0s - loss: 0.3008 - fn: 147.0000 - fp: 5048.0000 - tn: 24664.0000 - tp: 2141.0000 - accuracy: 0.8377 - precision: 0.2978 - recall: 0.9358 - auc: 0.9427 - val_loss: 0.2740 - val_fn: 57.0000 - val_fp: 1054.0000 - val_tn: 6338.0000 - val_tp: 551.0000 - val_accuracy: 0.8611 - val_precision: 0.3433 - val_recall: 0.9062 - val_auc: 0.9481
# Epoch 46/50
# 16/16 - 0s - loss: 0.3014 - fn: 154.0000 - fp: 4920.0000 - tn: 24792.0000 - tp: 2134.0000 - accuracy: 0.8414 - precision: 0.3025 - recall: 0.9327 - auc: 0.9422 - val_loss: 0.2911 - val_fn: 53.0000 - val_fp: 1116.0000 - val_tn: 6276.0000 - val_tp: 555.0000 - val_accuracy: 0.8539 - val_precision: 0.3321 - val_recall: 0.9128 - val_auc: 0.9476
# Epoch 47/50
# 16/16 - 0s - loss: 0.2995 - fn: 171.0000 - fp: 4800.0000 - tn: 24912.0000 - tp: 2117.0000 - accuracy: 0.8447 - precision: 0.3061 - recall: 0.9253 - auc: 0.9429 - val_loss: 0.3026 - val_fn: 46.0000 - val_fp: 1186.0000 - val_tn: 6206.0000 - val_tp: 562.0000 - val_accuracy: 0.8460 - val_precision: 0.3215 - val_recall: 0.9243 - val_auc: 0.9478
# Epoch 48/50
# 16/16 - 0s - loss: 0.3031 - fn: 168.0000 - fp: 4901.0000 - tn: 24811.0000 - tp: 2120.0000 - accuracy: 0.8416 - precision: 0.3020 - recall: 0.9266 - auc: 0.9419 - val_loss: 0.2993 - val_fn: 52.0000 - val_fp: 1129.0000 - val_tn: 6263.0000 - val_tp: 556.0000 - val_accuracy: 0.8524 - val_precision: 0.3300 - val_recall: 0.9145 - val_auc: 0.9478
# Epoch 49/50
# 16/16 - 0s - loss: 0.3054 - fn: 150.0000 - fp: 5056.0000 - tn: 24656.0000 - tp: 2138.0000 - accuracy: 0.8373 - precision: 0.2972 - recall: 0.9344 - auc: 0.9416 - val_loss: 0.3050 - val_fn: 46.0000 - val_fp: 1218.0000 - val_tn: 6174.0000 - val_tp: 562.0000 - val_accuracy: 0.8420 - val_precision: 0.3157 - val_recall: 0.9243 - val_auc: 0.9468
# Epoch 50/50
# 16/16 - 0s - loss: 0.2969 - fn: 145.0000 - fp: 4841.0000 - tn: 24871.0000 - tp: 2143.0000 - accuracy: 0.8442 - precision: 0.3068 - recall: 0.9366 - auc: 0.9440 - val_loss: 0.2947 - val_fn: 57.0000 - val_fp: 1089.0000 - val_tn: 6303.0000 - val_tp: 551.0000 - val_accuracy: 0.8568 - val_precision: 0.3360 - val_recall: 0.9062 - val_auc: 0.9476

# %% [markdown]
# ## Metrics

# %%
results = model.evaluate(val_ds, verbose=0)
for name, value in zip(model.metrics_names, results):
    print(name, ': ', value)
print()
# Out:
# loss :  0.2946699857711792
# fn :  57.0
# fp :  1089.0
# tn :  6303.0
# tp :  551.0
# accuracy :  0.8567500114440918
# precision :  0.33597561717033386
# recall :  0.90625
# auc :  0.9476027488708496
